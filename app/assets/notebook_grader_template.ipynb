# %% [markdown]
# <!-- STUDENT_INFO -->
# **ФИО:** Иванов Иван Иванович
# **Группа:** БПИ241

# %% [markdown]
# ## Инструкция
#
# Это шаблон для выполнения задания в системе **Notebook Grader**.
#
# - Заполните ячейку выше своими ФИО и группой. Строку `<!-- STUDENT_INFO -->` удалять нельзя — по ней сервер находит вашу анкету. Никакого другого текста в этой ячейке быть не должно.
# - Решение каждой задачи пишите **только** в ячейке с тегом `task:<код>` (теги уже проставлены ниже). Не удаляйте теги — без них сервер не найдёт вашу задачу и поставит 0 баллов.
# - Ячейка с тегом `setup` выполняется **перед каждой** задачей: импорты и общие переменные пишите туда.
# - Можно добавлять собственные ячейки между задачами для черновых расчётов — они не повлияют на проверку.
# - Перед сдачей убедитесь, что коды задач (`task:1`, `task:2`, ...) совпадают с теми, что указал преподаватель.

# %%
# Общие импорты выполняются перед каждой задачей.
import numpy as np
import pandas as pd

# %%
# Задача 1 — проверка по правильному ответу.
# Решение должно выводить ответ через print(...).
# Сравнивается stdout с ожидаемым значением.
result = 2 + 2
print(result)

# %%
# Задача 2 — проверка по набору тестов.
# Программа читает входные данные из stdin (input()) и печатает
# результат в stdout (print). Каждый тест-кейс запускается отдельно.
n = int(input())
print(n * n)

# %%
# Задача 3 — машинное сравнение (reference_assert).
# Преподаватель допишет проверочный код в конец ячейки.
# Завершение без исключений → полный балл,
# любое исключение (включая AssertionError) → 0 баллов.
def solve(x):
    return x * 2

# %% [markdown]
# ---
#
# **Напоминание.** Коды задач (`task:1`, `task:2`, `task:3`, ...) должны точно совпадать с кодами задач в карточке задания на сервере. Если преподаватель завёл задачи с кодами `A1`, `A2`, `A3` — переименуйте теги соответственно (например, `task:A1`).
